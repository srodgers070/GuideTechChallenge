# %%
def plotfile(filename):
    
    import numpy as np
    import matplotlib.pyplot as plt
    data = np.loadtxt(filename, skiprows=1, delimiter=',') #Load it in as an array
    plt.figure(figsize=(10,10))
    plt.title("%s X vs Y data" %filename)
    plt.plot(data[:,0], data[:,1], ls='--', marker="o", label='Missile Positions')
    plt.plot(data[:,2], data[:,3], ls = '-', marker='^', label="Target Positions")
    plt.legend(loc='best')
    plt.show()
plotfile('testing.csv')

# %%
# %matplotlib notebook
plotfile('Replicating.csv')
# Out:
# <img src="data:image/png;base64,..." width="999.4166666666666">

# %%
import numpy as np
import matplotlib.pyplot as plt
filename='Replicating.csv'
data = np.loadtxt(filename, skiprows=1, delimiter=',') #Load it in as an array
print(len(data))
plt.figure(1,figsize=(15,10))
plt.subplot(211)
plt.title("%s X vs Y data" %filename)
plt.plot(data[:,0], data[:,1], ls='--', marker="o", label='Missile Positions')
plt.plot(data[:,2], data[:,3], ls = '-', marker='^', label="Target Positions")
plt.legend(loc='best')
plt.xlabel("X Coordinate [m]")
plt.ylabel("Y Coordinate [m]")
plt.subplot(212)
plt.plot(data[:,6],data[:,5], ls = "-", Label='Separation')
plt.legend(loc='best')
plt.ylabel('Separation [m]')
plt.xlabel('Time (s)')
plt.savefig("test")
# Out:
# 701

# %%
plt.annotate?

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as ani
def animatemyplot(i):
    mxdata=FileData[:,0][i+1]
    mydata=FileData[:,1][i+1]
    txdata=FileData[:,2][i+1]
    tydata=FileData[:,3][i+1]
    time=FileData[:,6][i+1]
    plot=plt.plot(mxdata,mydata, c='b', ls='-',marker='o')
    plot=plt.plot(txdata, tydata, c='k', ls='--', marker="^")
    mislabel=plt.annotate('Missile', (mxdata+10,mydata+10))
    targlabel=plt.annotate('Target', (txdata+10,tydata+10))
    plt.annotate.remove()
    

    
filename='Replicating.csv'
FileData = np.loadtxt(filename, skiprows=1, delimiter=',') #Load it in as an array
frames=len(FileData)
fig=plt.figure(figsize=(10,10))
plt.xlabel('X Coordinate [m]')
plt.ylabel('Y Coordinate [m]')
animator=ani.FuncAnimation(fig, animatemyplot,frames,interval=10,repeat=False)


# Writer=ani.writers['ffmpeg']
# writer=Writer(fps=15,metadata=dict(artist='Spencer Rodgers', date="1/5/2021"), bitrate=1800)
# animator.save("PG.mp4",writer)
# Out:
# <img src="data:image/png;base64,..." width="999.4166666666666">

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as ani
filename='ProNav.csv'
data = np.loadtxt(filename, skiprows=1, delimiter=',') #Load it in as an array
print(len(data))
fig=plt.figure(1,figsize=(15,10))
plt.subplot(211)
plt.title("%s X vs Y data" %filename)
plt.plot(data[:,0], data[:,1], ls='--', marker="o", label='Missile Positions')
plt.plot(data[:,2], data[:,3], ls = '-', marker='^', label="Target Positions")
plt.legend(loc='best')
plt.xlabel("X Coordinate [m]")
plt.ylabel("Y Coordinate [m]")
plt.subplot(212)
plt.plot(data[:,6],data[:,5], ls = "-", Label='Separation')
plt.legend(loc='best')
plt.ylabel('Separation [m]')
plt.xlabel('Time (s)')
plt.show()
# plt.savefig("ProNavTest3")
# print(data[:,0])
# Out:
# 701

# %%
# %matplotlib notebook
def animatemyplot(i):
    mxdata=FileData[:,0][i+1]
    mydata=FileData[:,1][i+1]
    txdata=FileData[:,2][i+1]
    tydata=FileData[:,3][i+1]
    plot=plt.plot(mxdata,mydata, c='b', ls='-',marker='o')
    plot=plt.plot(txdata, tydata, c='k', ls='--', marker="^")
    
    
filename='ProNav.csv'
FileData = np.loadtxt(filename, skiprows=1, delimiter=',') #Load it in as an array
frames=len(FileData)
fig=plt.figure(figsize=(10,10))
# animator=ani.FuncAnimation(fig, animatemyplot,frames,repeat=True)
# Out:
# <img src="data:image/png;base64,..." width="999.4166666666666">

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

coherence_matrices = np.random.rand(80,3,3)

fig = plt.figure()
ax1 = fig.add_subplot(1, 1, 1)
# add another axes at the top left corner of the figure
axtext = fig.add_axes([0.0,0.95,0.1,0.05])
# turn the axis labels/spines/ticks off
axtext.axis("off")

cax1 = ax1.matshow(coherence_matrices[0], cmap='YlOrRd')
# place the text to the other axes
time = axtext.text(2,0.5, str(0), ha="left", va="top")


def animate(i):
    cax1.set_array(coherence_matrices[i])

    time.set_text('Time = '+str(i))

    return cax1, time,

anim = animation.FuncAnimation(fig, animate, frames=len(coherence_matrices),
                                    interval=80, blit=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
# %matplotlib notebook
